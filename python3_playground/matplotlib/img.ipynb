# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread('./matplotlib/baby_yoda.jpeg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (2048, 2048, 3)

# %%
#
# Grayscale
#

# %%
copyImg = img.copy()

#get the average of each pixel
average_pixel_values = np.mean(copyImg, axis=2, keepdims=True)

# %%
average_pixel_values.shape
# Out:
# (2048, 2048, 1)

# %%
#create the grey image by "stacking" three copies of these grey values together
greyImage = np.concatenate([average_pixel_values]*3, axis=2)

#make sure to cast the final image back to integers
greyImage = greyImage.astype(int)

# %%
greyImage.shape
# Out:
# (2048, 2048, 3)

# %%
plt.imshow(greyImage)

# %%
#
#  Reserved all rows
#

# %%
copyImg = img.copy()
copyImg1 = img.copy()

# reverse all the rows in my image
vFlipImg = copyImg[::-1]

# reverse all columns
hFlipImg = copyImg1[:,::-1]

# %%
plt.imshow(vFlipImg)

# %%
plt.imshow(hFlipImg)

# %%
img
# Out:
# array([[[223, 239, 228],
#         [196, 220, 204],
#         [197, 220, 204],
#         ...,
#         [197, 220, 204],
#         [197, 221, 205],
#         [196, 220, 204]],
#
#        [[222, 238, 227],
#         [195, 219, 203],
#         [196, 219, 203],
#         ...,
#         [196, 219, 203],
#         [195, 219, 203],
#         [195, 219, 203]],
#
#        [[222, 238, 227],
#         [195, 219, 203],
#         [196, 219, 203],
#         ...,
#         [195, 219, 203],
#         [197, 220, 204],
#         [196, 219, 203]],
#
#        ...,
#
#        [[ 57,  51,  37],
#         [ 59,  53,  39],
#         [ 62,  54,  41],
#         ...,
#         [ 46,  43,  28],
#         [ 48,  42,  28],
#         [ 49,  43,  29]],
#
#        [[ 64,  56,  35],
#         [ 63,  56,  37],
#         [ 60,  57,  40],
#         ...,
#         [ 48,  45,  30],
#         [ 51,  45,  31],
#         [ 51,  45,  31]],
#
#        [[ 60,  54,  32],
#         [ 56,  50,  28],
#         [ 50,  47,  30],
#         ...,
#         [ 51,  45,  31],
#         [ 52,  46,  32],
#         [ 52,  44,  31]]], dtype=uint8)

# %%
vFlipImg
# Out:
# array([[[ 60,  54,  32],
#         [ 56,  50,  28],
#         [ 50,  47,  30],
#         ...,
#         [ 51,  45,  31],
#         [ 52,  46,  32],
#         [ 52,  44,  31]],
#
#        [[ 64,  56,  35],
#         [ 63,  56,  37],
#         [ 60,  57,  40],
#         ...,
#         [ 48,  45,  30],
#         [ 51,  45,  31],
#         [ 51,  45,  31]],
#
#        [[ 57,  51,  37],
#         [ 59,  53,  39],
#         [ 62,  54,  41],
#         ...,
#         [ 46,  43,  28],
#         [ 48,  42,  28],
#         [ 49,  43,  29]],
#
#        ...,
#
#        [[222, 238, 227],
#         [195, 219, 203],
#         [196, 219, 203],
#         ...,
#         [195, 219, 203],
#         [197, 220, 204],
#         [196, 219, 203]],
#
#        [[222, 238, 227],
#         [195, 219, 203],
#         [196, 219, 203],
#         ...,
#         [196, 219, 203],
#         [195, 219, 203],
#         [195, 219, 203]],
#
#        [[223, 239, 228],
#         [196, 220, 204],
#         [197, 220, 204],
#         ...,
#         [197, 220, 204],
#         [197, 221, 205],
#         [196, 220, 204]]], dtype=uint8)

# %%
hFlipImg
# Out:
# array([[[196, 220, 204],
#         [197, 221, 205],
#         [197, 220, 204],
#         ...,
#         [197, 220, 204],
#         [196, 220, 204],
#         [223, 239, 228]],
#
#        [[195, 219, 203],
#         [195, 219, 203],
#         [196, 219, 203],
#         ...,
#         [196, 219, 203],
#         [195, 219, 203],
#         [222, 238, 227]],
#
#        [[196, 219, 203],
#         [197, 220, 204],
#         [195, 219, 203],
#         ...,
#         [196, 219, 203],
#         [195, 219, 203],
#         [222, 238, 227]],
#
#        ...,
#
#        [[ 49,  43,  29],
#         [ 48,  42,  28],
#         [ 46,  43,  28],
#         ...,
#         [ 62,  54,  41],
#         [ 59,  53,  39],
#         [ 57,  51,  37]],
#
#        [[ 51,  45,  31],
#         [ 51,  45,  31],
#         [ 48,  45,  30],
#         ...,
#         [ 60,  57,  40],
#         [ 63,  56,  37],
#         [ 64,  56,  35]],
#
#        [[ 52,  44,  31],
#         [ 52,  46,  32],
#         [ 51,  45,  31],
#         ...,
#         [ 50,  47,  30],
#         [ 56,  50,  28],
#         [ 60,  54,  32]]], dtype=uint8)
